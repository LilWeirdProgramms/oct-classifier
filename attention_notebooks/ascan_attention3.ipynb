# %%
import numpy as np
import BinaryReader
import TFRecordsHandler
import tensorflow as tf
import sklearn

# %%
16*16*16
# Out:
# 4096

# %%
def instance_condition(file_name, instance_label):
    position_string = file_name.split(".")[0]
    b_pos_str, c_pos_str = position_string.split("_")
    b_pos = int(b_pos_str[1:])
    c_pos = int(c_pos_str[1:])
    instance_label *= 2
    if b_pos == 0 and c_pos == 0:
        is_corner = True
    elif b_pos == 19 and c_pos == 19:
        is_corner = True
        instance_label += 1
    else:
        is_corner = False
    return is_corner, instance_label

# %%
import os
data_location = "/mnt/NewHDD/tfrecords"
all_input_files = []
all_labels = []
for instance in os.listdir(data_location):
    label = int(instance[0])
    instance = os.path.join(data_location, instance)
    for file in os.listdir(instance):
        is_corner_instance, corner_label = instance_condition(file, label)
        if is_corner_instance:
            all_input_files.append(os.path.join(instance, file))
            all_labels.append(corner_label)

# %%
import os
data_location = "/mnt/NewHDD/tfrecords"
all_input_files = []
all_labels = []
for instance in os.listdir(data_location):
    label = int(instance[0])
    instance_value = int(instance.split("_")[-1])
    if not instance_value in bad_files:
        instance = os.path.join(data_location, instance)
        for file in os.listdir(instance):
            is_corner_instance, corner_label = instance_condition(file, label)
            if is_corner_instance:
                all_input_files.append(os.path.join(instance, file))
                all_labels.append(corner_label)

# %%
bad_files = [19886
,19618
,29915
,20843
,29333
,22619
,22910
,20304
,23237
,23423]

# %%
dataset = TFRecordsHandler.get_dataset_small(all_input_files)

# %%
mean_scans = []
var_scans = []
for elem in dataset:
    mean_scans.append(np.mean(elem[0].numpy().reshape((1536, 102*102)), axis=1))
    var_scans.append(np.var(elem[0].numpy().reshape((1536, 102*102)), axis=1))

# %%
mean_scans_sub = []
var_scans_sub = []
tryout = []
i = 0
for elem, mean, var in zip(dataset, mean_scans, var_scans):
    to_calc = (elem[0].numpy().reshape((1536, 102*102)) - mean.reshape((1536, 1)))
              / var.reshape((1536, 1))**0.5
    mean_scans_sub.append(np.mean(to_calc, axis=1))
    var_scans_sub.append(np.var(to_calc, axis=1))
    #tryout.append(to_calc.reshape((15980544,)))
    #if i == 20:
    #    break
    i += 1

# %%
all_input_files
# Out:
# ['/mnt/NewHDD/tfrecords/0_24012/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_24012/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30720/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30720/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_13025/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_13025/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__7698/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__7698/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_13994/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_13994/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_20472/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_20472/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_17600/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_17600/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_10419/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_10419/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_13746/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_13746/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_17129/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_17129/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__9772/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__9772/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30984/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30984/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_18044/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_18044/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__7489/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__7489/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_29881/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_29881/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__8920/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__8920/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_24362/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_24362/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_15780/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_15780/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30093/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_30093/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_25201/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_25201/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__6316/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1__6316/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__8042/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0__8042/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_15453/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_15453/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_12417/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_12417/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_24825/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/0_24825/b0_c0.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_14415/b19_c19.tfrecords',
#  '/mnt/NewHDD/tfrecords/1_14415/b0_c0.tfrecords']

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=1, perplexity=4,n_iter = 2000)
var_embedding = tsne.fit_transform(var_scans)
# Out:
# /home/julius/miniconda3/envs/tf-test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/julius/miniconda3/envs/tf-test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 13 nearest neighbors...
# [t-SNE] Indexed 52 samples in 0.000s...
# [t-SNE] Computed neighbors for 52 samples in 0.009s...
# [t-SNE] Computed conditional probabilities for sample 52 / 52
# [t-SNE] Mean sigma: 4630025.009143
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.400017
# [t-SNE] KL divergence after 2000 iterations: 0.306722

# %%
from umap import UMAP
umap = UMAP(n_neighbors=8)
var_embedding = umap.fit_transform(mean_scans)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame()
df["y"] = all_labels
df["comp-1"] = var_embedding[:,0]
df["comp-2"] = var_embedding[:,1]

fig = plt.figure(figsize=(14,10))
sns.scatterplot(x="comp-1", y="comp-2", hue=df.y.tolist(),
                palette=sns.color_palette("hls", 4),
                data=df).set(title="Background raw A-Scans with T-SNE projection")
# Out:
# [Text(0.5, 1.0, 'Background raw A-Scans with T-SNE projection')]

# %% [markdown]
# # TODO: Mean of all Variances plot
# # TODO: substsract background mean from all ascans

# %%
outliers_10 = []
for i, value in enumerate(var_embedding[:, 0]):
    if -20 < value < 20:
        outliers_10.append(all_input_files[i])

# %%
outliers_30 = []
for i, value in enumerate(var_embedding[:,1]):
    if value > 8.5:
        outliers_30.append(all_input_files[i])

# %%
outliers_20 = []
for i, value in enumerate(var_embedding[:,0]):
    if value > 10:
        outliers_20.append(all_input_files[i])

# %%
import BinaryReader
import InputList

br = BinaryReader.BinaryReader()
gen = br.instance_from_binaries_generator(InputList.diabetic_training_files[2:3])
i = 0
for elem in gen:
    # if i==0:
    #     border_elem = elem
    #     mean_border_ascan = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
    #     var_border_ascan = np.var(elem[0].reshape((1536, 102*102)), axis=1)
    i += 1
    if i == 31:
        retina_elem1 = elem
        mean_retina_ascan1 = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
        var_retina_ascan1 = np.var(elem[0].reshape((1536, 102*102)), axis=1)
    if i == 50:
        retina_elem2 = elem
        mean_retina_ascan2 = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
        var_retina_ascan2 = np.var(elem[0].reshape((1536, 102*102)), axis=1)
        break

# %%
import os
os.chdir("../")

# %%
import BinaryReader
import InputList
import numpy as np

br = BinaryReader.BinaryReader()
gen = br.instance_from_binaries_generator([InputList.diabetic_training_files[1]])
i = 0
for elem in gen:
    border_elem = elem
    mean_border_ascan_h3 = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
    var_border_ascan_h5 = np.var(elem[0].reshape((1536, 102*102)), axis=1)
    break
# Out:
# 2022-06-30 17:27:34.239325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 17:27:34.268231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-30 17:27:34.268351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
gen = br.instance_from_binaries_generator(InputList.healthy_training_files[:1])
i = 0
for elem in gen:
    # if i==0:
    #     border_elem = elem
    #     mean_border_ascan = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
    #     var_border_ascan = np.var(elem[0].reshape((1536, 102*102)), axis=1)
    i += 1
    if i == 31:
        retina_elem3 = elem
        mean_retina_ascan3 = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
        var_retina_ascan3 = np.var(elem[0].reshape((1536, 102*102)), axis=1)
    if i == 50:
        retina_elem4 = elem
        mean_retina_ascan4 = np.mean(elem[0].reshape((1536, 102*102)), axis=1)
        var_retina_ascan4 = np.var(elem[0].reshape((1536, 102*102)), axis=1)
        break

# TODO: Find out what is the last i (102 mal 102 teile...)

# %%
retina1 = retina_elem2[0]
retina2 = retina_elem1[0]
border1 = border_elem[0]
all_elem = [border1, retina1, retina2]

# %%
new_all = []
for elem in all_elem:
    new_all.append(elem.astype("int64") - 32743)

# %%
np.mean(new_all[0])
# Out:
# 0.38034049404075354

# %%
newer_all = []
for elem in new_all:
    newer_all.append(np.abs(elem))

# %%
newer_all[0].shape
# Out:
# (1536, 102, 102, 1)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,10))
plt.title("Comparison of Normalized Absolut Values between A-scans")
for elem in newer_all:
    plt.plot(np.mean(elem.reshape((1536, 102*102)), axis=1))
plt.legend(["Boarder", "Retina 1", "Retina 2"])
plt.savefig("normalize_absolut.png")
fig = plt.figure(figsize=(18,10))
for elem in newer_all:
    plt.plot(np.var(elem.reshape((1536, 102*102)), axis=1))

# %%
def euclidean_distance(x,y):
  return (sum(pow(a-b,2) for a, b in zip(x, y)))**0.5

# %%
#scans = [mean_border_ascan_d1, mean_border_ascan_d2, mean_border_ascan_h1, mean_border_ascan_h2, mean_border_ascan_h3]
scans = [var_border_ascan_d1, var_border_ascan_d2, var_border_ascan_h1, var_border_ascan_h2, var_border_ascan_h3, var_border_ascan_h4]
res = []
for scan in scans:
    res2 = []
    for scan2 in scans:
        res2.append(euclidean_distance(scan,scan2))
    res.append(res2)

# %%
from sklearn.manifold import TSNE
embedding = TSNE().fit_transform(np.array([var_border_ascan_h5, var_border_ascan_h4]))
# Out:
# /home/julius/miniconda3/envs/tf-test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/julius/miniconda3/envs/tf-test/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
(24012, 13025), (13994, 14415) , (19886, 29915)
(0, 6), (10, 70), (4, 18)
# Out:
# array([ 158.39442, -158.39442], dtype=float32)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(14,10))
plt.plot()
plt.plot(var_scans[6])
plt.plot(var_scans[70])
plt.plot(var_scans[4])
plt.legend(["Healthy1","Diabetic1", "Diabetic2", "Diabetic"])
plt.title("Comparison of Varainces between background A-scans")
#plt.savefig("variance_plot.png")
# Out:
# Text(0.5, 1.0, 'Comparison of Varainces between background A-scans')

# %%
mean_border_ascan_h2[400:800]
# Out:
# (1536,)

# %%
# TODO: Move to Utils file?
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,18))
plt.hbar(mean_border_ascan_h2[500:700], ".")
plt.plot(mean_border_ascan_h1[500:700], ".")
plt.plot(mean_border_ascan_d1[500:700], ".")
plt.legend(["Flipped", "Healthy", "Diabetic"])
plt.title("Comparison of Mean between A-scans")
plt.savefig("mean_plot.png")

# %%
diciti = {"values": [], "labels":[]}

# %%
def helper(th, my_diciti):
    values = th[0].reshape((1536, 102*102))
    for i in range(102*102):
        my_diciti["values"].append(values[:, i])
        my_diciti["labels"].append(th[1])
    return my_diciti

# %%
helper(border_elem, diciti)
# Out:
# {'values': [array([35168, 34208, 32960, ..., 32608, 36064, 34944], dtype=uint16),
#   array([35040, 35104, 34976, ..., 28448, 29536, 32128], dtype=uint16),
#   array([32992, 33376, 33184, ..., 32288, 32064, 32576], dtype=uint16),
#   array([34272, 34720, 32384, ..., 31680, 30720, 33376], dtype=uint16),
#   array([33568, 33856, 33088, ..., 27616, 26944, 32544], dtype=uint16),
#   array([38112, 35264, 35328, ..., 34240, 27712, 28512], dtype=uint16),
#   array([33248, 31488, 35520, ..., 35776, 34400, 32736], dtype=uint16),
#   array([29600, 28640, 33536, ..., 32000, 32064, 29312], dtype=uint16),
#   array([33184, 31488, 31200, ..., 32768, 33792, 33600], dtype=uint16),
#   array([33568, 33216, 33856, ..., 29856, 24320, 29856], dtype=uint16),
#   array([32512, 33824, 32768, ..., 33760, 30848, 33536], dtype=uint16),
#   array([33088, 26240, 34976, ..., 35648, 33248, 35264], dtype=uint16),
#   array([36512, 35072, 33408, ..., 35936, 34784, 31520], dtype=uint16),
#   array([32640, 32096, 34016, ..., 30784, 32672, 32352], dtype=uint16),
#   array([34144, 32512, 32160, ..., 34208, 31872, 29344], dtype=uint16),
#   array([32960, 26176, 31808, ..., 35168, 36000, 35456], dtype=uint16),
#   array([34016, 35200, 35008, ..., 29568, 24640, 27872], dtype=uint16),
#   array([32928, 37568, 33792, ..., 34368, 34912, 35584], dtype=uint16),
#   array([32672, 34176, 31456, ..., 25344, 30368, 32832], dtype=uint16),
#   array([32768, 30592, 28320, ..., 36640, 34752, 34176], dtype=uint16),
#   array([32800, 34336, 32960, ..., 31488, 31232, 31584], dtype=uint16),
#   array([34784, 35104, 35808, ..., 35008, 35392, 32640], dtype=uint16),
#   array([34080, 33504, 36832, ..., 30656, 30912, 29536], dtype=uint16),
#   array([33056, 35392, 34976, ..., 33056, 31680, 30560], dtype=uint16),
#   array([33952, 32832, 32352, ..., 35872, 35424, 37056], dtype=uint16),
#   array([33824, 36544, 35904, ..., 31776, 31040, 27264], dtype=uint16),
#   array([33824, 35104, 33824, ..., 35552, 33696, 35424], dtype=uint16),
#   array([32960, 34208, 33056, ..., 32224, 33056, 33280], dtype=uint16),
#   array([33472, 33696, 32704, ..., 28832, 33088, 31232], dtype=uint16),
#   array([29728, 28224, 33696, ..., 34208, 34592, 33920], dtype=uint16),
#   array([32576, 34400, 36768, ..., 31776, 31680, 33408], dtype=uint16),
#   array([32032, 32864, 32512, ..., 34688, 34016, 32864], dtype=uint16),
#   array([32928, 32672, 30720, ..., 31936, 32736, 33536], dtype=uint16),
#   array([33408, 32992, 32224, ..., 32896, 33152, 34656], dtype=uint16),
#   array([36224, 34528, 31808, ..., 34304, 33888, 35488], dtype=uint16),
#   array([29952, 29440, 34144, ..., 31392, 36256, 33600], dtype=uint16),
#   array([34976, 33600, 34816, ..., 30176, 31584, 33664], dtype=uint16),
#   array([33664, 35488, 33984, ..., 33664, 34560, 33728], dtype=uint16),
#   array([34048, 37312, 35264, ..., 29088, 32864, 29856], dtype=uint16),
#   array([27040, 31840, 32576, ..., 32800, 32448, 33024], dtype=uint16),
#   array([33216, 33824, 31552, ..., 32448, 33056, 34976], dtype=uint16),
#   array([34784, 34848, 32704, ..., 33216, 34816, 34240], dtype=uint16),
#   array([34080, 31264, 35008, ..., 24896, 29664, 28864], dtype=uint16),
#   array([27968, 26368, 27744, ..., 35520, 36608, 35520], dtype=uint16),
#   array([31264, 31456, 34560, ..., 34752, 33728, 33408], dtype=uint16),
#   array([30464, 28288, 30048, ..., 32800, 33216, 33280], dtype=uint16),
#   array([32928, 33568, 34912, ..., 29600, 30272, 32480], dtype=uint16),
#   array([35136, 36416, 35584, ..., 31328, 32576, 33792], dtype=uint16),
#   array([32288, 35040, 31232, ..., 33920, 35232, 32960], dtype=uint16),
#   array([30880, 30176, 32064, ..., 35136, 37984, 37344], dtype=uint16),
#   array([32224, 33184, 33056, ..., 30336, 33760, 39008], dtype=uint16),
#   array([32064, 32960, 34528, ..., 32672, 32224, 33216], dtype=uint16),
#   array([35616, 34400, 35744, ..., 26592, 24256, 29376], dtype=uint16),
#   array([31936, 32832, 36384, ..., 32416, 35488, 32608], dtype=uint16),
#   array([29600, 30048, 33536, ..., 33760, 35136, 35488], dtype=uint16),
#   array([35296, 34880, 34688, ..., 29184, 32224, 31136], dtype=uint16),
#   array([34848, 37152, 36832, ..., 34400, 34944, 35296], dtype=uint16),
#   array([33728, 30336, 37408, ..., 31264, 31136, 35296], dtype=uint16),
#   array([31488, 28320, 31104, ..., 32512, 31840, 34464], dtype=uint16),
#   array([31200, 26912, 29952, ..., 30240, 32000, 30688], dtype=uint16),
#   array([34848, 33504, 35296, ..., 31040, 33216, 30784], dtype=uint16),
#   array([33376, 31360, 33440, ..., 32800, 31872, 33728], dtype=uint16),
#   array([32192, 29568, 34464, ..., 30240, 29856, 32128], dtype=uint16),
#   array([33856, 35328, 34112, ..., 30688, 34336, 33792], dtype=uint16),
#   array([32928, 31296, 32224, ..., 28960, 26464, 31680], dtype=uint16),
#   array([31392, 27040, 31264, ..., 31392, 33504, 32128], dtype=uint16),
#   array([31936, 31200, 32192, ..., 31072, 31296, 33856], dtype=uint16),
#   array([33856, 30144, 32256, ..., 35712, 36032, 34144], dtype=uint16),
#   array([33184, 33920, 35040, ..., 22016, 25728, 30016], dtype=uint16),
#   array([34784, 34464, 33888, ..., 33984, 34656, 35200], dtype=uint16),
#   array([37632, 33216, 30144, ..., 29632, 35552, 32544], dtype=uint16),
#   array([34400, 33888, 36512, ..., 27424, 33952, 29760], dtype=uint16),
#   array([24032, 33152, 33696, ..., 36544, 34944, 33440], dtype=uint16),
#   array([33024, 34848, 33536, ..., 36192, 36128, 34592], dtype=uint16),
#   array([37056, 29120, 27744, ..., 33600, 37344, 36320], dtype=uint16),
#   array([36768, 39520, 35392, ..., 33600, 30976, 34432], dtype=uint16),
#   array([30688, 34912, 34240, ..., 35872, 33152, 31232], dtype=uint16),
#   array([36576, 36384, 34304, ..., 34528, 32704, 29728], dtype=uint16),
#   array([35680, 36384, 38688, ..., 36768, 36256, 34368], dtype=uint16),
#   array([33760, 34304, 35680, ..., 32672, 34560, 35808], dtype=uint16),
#   array([31040, 30752, 33728, ..., 31040, 34720, 34688], dtype=uint16),
#   array([33952, 36960, 38112, ..., 31392, 35392, 30944], dtype=uint16),
#   array([32224, 34432, 30816, ..., 21728, 30592, 31328], dtype=uint16),
#   array([31648, 30656, 34720, ..., 33088, 34880, 34240], dtype=uint16),
#   array([36960, 29856, 30496, ..., 35904, 30848, 29504], dtype=uint16),
#   array([33568, 30784, 29824, ..., 35168, 32704, 33088], dtype=uint16),
#   array([31840, 29408, 30752, ..., 32288, 32352, 32736], dtype=uint16),
#   array([29024, 31072, 33696, ..., 32032, 27520, 27328], dtype=uint16),
#   array([33216, 28320, 29664, ..., 29024, 31584, 31008], dtype=uint16),
#   array([34048, 34656, 35552, ..., 33184, 31520, 33664], dtype=uint16),
#   array([35232, 34944, 36160, ..., 33440, 34048, 35296], dtype=uint16),
#   array([35648, 29632, 28800, ..., 31552, 31040, 26784], dtype=uint16),
#   array([32512, 35008, 35296, ..., 30272, 30816, 32128], dtype=uint16),
#   array([39392, 39520, 36672, ..., 34720, 33312, 34528], dtype=uint16),
#   array([34592, 35936, 32896, ..., 35168, 34400, 35328], dtype=uint16),
#   array([32640, 35520, 37152, ..., 29728, 29088, 32160], dtype=uint16),
#   array([32640, 31360, 32736, ..., 31136, 31392, 36000], dtype=uint16),
#   array([37792, 38848, 35072, ..., 31488, 29792, 32544], dtype=uint16),
#   array([34240, 27808, 27552, ..., 34720, 33856, 34048], dtype=uint16),
#   array([28512, 31776, 34112, ..., 27520, 30400, 31904], dtype=uint16),
#   array([37888, 36576, 35680, ..., 34080, 35616, 32512], dtype=uint16),
#   array([36192, 32160, 29760, ..., 31808, 29632, 30368], dtype=uint16),
#   array([36992, 36224, 35456, ..., 34176, 31744, 35360], dtype=uint16),
#   array([36288, 34336, 35712, ..., 31200, 31072, 31712], dtype=uint16),
#   array([33792, 35808, 34560, ..., 32960, 33824, 31936], dtype=uint16),
#   array([35296, 35136, 30880, ..., 33088, 33664, 31744], dtype=uint16),
#   array([34176, 36128, 34784, ..., 30624, 29984, 31008], dtype=uint16),
#   array([37792, 35328, 36160, ..., 35584, 32928, 29472], dtype=uint16),
#   array([31776, 35200, 37120, ..., 35392, 34816, 33920], dtype=uint16),
#   array([30816, 31584, 34944, ..., 32192, 33920, 33312], dtype=uint16),
#   array([33472, 32064, 34048, ..., 32224, 32512, 34624], dtype=uint16),
#   array([34784, 36096, 34016, ..., 33472, 32192, 29984], dtype=uint16),
#   array([34496, 32640, 33440, ..., 33280, 33824, 30816], dtype=uint16),
#   array([30560, 32480, 33504, ..., 35520, 35168, 35136], dtype=uint16),
#   array([37536, 35040, 36096, ..., 35424, 34912, 35776], dtype=uint16),
#   array([35424, 33888, 33888, ..., 33696, 33184, 35072], dtype=uint16),
#   array([34592, 34208, 33216, ..., 32448, 35584, 34240], dtype=uint16),
#   array([30112, 29824, 35680, ..., 32288, 35648, 35104], dtype=uint16),
#   array([35616, 34464, 33760, ..., 32192, 30272, 28064], dtype=uint16),
#   array([37824, 36960, 35840, ..., 34784, 33248, 34976], dtype=uint16),
#   array([32960, 32608, 32288, ..., 31392, 26912, 33920], dtype=uint16),
#   array([30592, 29152, 27712, ..., 33824, 33600, 32864], dtype=uint16),
#   array([33600, 34432, 32896, ..., 31712, 31552, 31264], dtype=uint16),
#   array([37632, 33824, 35744, ..., 35904, 34080, 35104], dtype=uint16),
#   array([36960, 35616, 34016, ..., 34688, 31264, 30112], dtype=uint16),
#   array([35840, 33696, 36000, ..., 33216, 33632, 33024], dtype=uint16),
#   array([34976, 32512, 35648, ..., 39584, 35392, 35072], dtype=uint16),
#   array([35776, 34496, 35680, ..., 35072, 33120, 32416], dtype=uint16),
#   array([35392, 35168, 34656, ..., 34688, 34272, 34112], dtype=uint16),
#   array([32256, 34144, 34144, ..., 34272, 32416, 34816], dtype=uint16),
#   array([34752, 35776, 31904, ..., 33024, 27968, 33408], dtype=uint16),
#   array([30272, 33568, 31808, ..., 34592, 35264, 34336], dtype=uint16),
#   array([36064, 35328, 37120, ..., 31680, 32480, 32480], dtype=uint16),
#   array([33344, 33984, 33216, ..., 35712, 33184, 33632], dtype=uint16),
#   array([33344, 31584, 30592, ..., 30784, 32416, 32544], dtype=uint16),
#   array([35712, 35808, 31616, ..., 28992, 34432, 33216], dtype=uint16),
#   array([35136, 34624, 31968, ..., 33152, 35840, 34400], dtype=uint16),
#   array([26976, 33920, 34240, ..., 33120, 31360, 34464], dtype=uint16),
#   array([36128, 36128, 34464, ..., 35904, 29984, 33216], dtype=uint16),
#   array([36576, 36320, 35104, ..., 31392, 34272, 32480], dtype=uint16),
#   array([36512, 37120, 37664, ..., 30528, 31840, 30688], dtype=uint16),
#   array([32256, 34752, 35232, ..., 31936, 30816, 32608], dtype=uint16),
#   array([32704, 37024, 33152, ..., 30272, 34336, 33088], dtype=uint16),
#   array([34848, 33856, 33920, ..., 32864, 30496, 33728], dtype=uint16),
#   array([33792, 33760, 34304, ..., 30112, 26848, 33376], dtype=uint16),
#   array([30944, 29984, 32064, ..., 35264, 36608, 37376], dtype=uint16),
#   array([35264, 34848, 32800, ..., 35104, 32992, 30784], dtype=uint16),
#   array([32832, 32128, 33376, ..., 34368, 36640, 33792], dtype=uint16),
#   array([32736, 34560, 33728, ..., 31936, 27936, 30976], dtype=uint16),
#   array([34848, 34976, 36096, ..., 32704, 32448, 34272], dtype=uint16),
#   array([33760, 32896, 32288, ..., 33600, 35168, 36608], dtype=uint16),
#   array([31168, 33568, 34016, ..., 34848, 33664, 36064], dtype=uint16),
#   array([34496, 35232, 33568, ..., 31840, 29184, 34336], dtype=uint16),
#   array([33600, 32864, 34880, ..., 32160, 32096, 33152], dtype=uint16),
#   array([37024, 37248, 36608, ..., 33952, 29344, 27680], dtype=uint16),
#   array([31200, 35808, 37120, ..., 37248, 37824, 38688], dtype=uint16),
#   array([32928, 34208, 34784, ..., 32960, 33600, 34016], dtype=uint16),
#   array([36288, 36448, 35616, ..., 31904, 31072, 33792], dtype=uint16),
#   array([35712, 37760, 36768, ..., 35872, 35328, 32160], dtype=uint16),
#   array([33568, 32928, 39136, ..., 31296, 30432, 30112], dtype=uint16),
#   array([32672, 34976, 33696, ..., 30720, 32384, 34112], dtype=uint16),
#   array([33376, 29664, 29920, ..., 28160, 30560, 29696], dtype=uint16),
#   array([35872, 34880, 32256, ..., 33696, 31776, 29952], dtype=uint16),
#   array([35136, 34016, 32736, ..., 33824, 36192, 31936], dtype=uint16),
#   array([30720, 33440, 32896, ..., 32640, 31424, 33536], dtype=uint16),
#   array([34240, 36960, 37440, ..., 34208, 31840, 34112], dtype=uint16),
#   array([33568, 34208, 38688, ..., 25920, 28384, 28448], dtype=uint16),
#   array([29664, 31648, 35424, ..., 34880, 31168, 33536], dtype=uint16),
#   array([32736, 32608, 34720, ..., 32032, 29920, 31072], dtype=uint16),
#   array([34208, 33312, 31072, ..., 28992, 39168, 37888], dtype=uint16),
#   array([36736, 34112, 33184, ..., 33120, 26272, 25024], dtype=uint16),
#   array([34528, 36576, 35968, ..., 33952, 35104, 34688], dtype=uint16),
#   array([38048, 35648, 34080, ..., 35744, 32896, 33472], dtype=uint16),
#   array([34848, 33344, 38432, ..., 33056, 25824, 32384], dtype=uint16),
#   array([29632, 34944, 36544, ..., 34880, 35648, 36128], dtype=uint16),
#   array([35776, 36128, 33824, ..., 35744, 36800, 36160], dtype=uint16),
#   array([35328, 31520, 34432, ..., 36736, 33984, 37344], dtype=uint16),
#   array([38688, 36736, 34784, ..., 34944, 34240, 32352], dtype=uint16),
#   array([33152, 34624, 33504, ..., 30048, 35072, 36416], dtype=uint16),
#   array([36288, 38368, 36704, ..., 36064, 36800, 34720], dtype=uint16),
#   array([35904, 39328, 36288, ..., 31808, 35808, 36064], dtype=uint16),
#   array([35904, 34944, 33888, ..., 34720, 33184, 34848], dtype=uint16),
#   array([35072, 32352, 36832, ..., 33984, 32608, 32960], dtype=uint16),
#   array([35040, 35552, 39104, ..., 33952, 30432, 36192], dtype=uint16),
#   array([35936, 33312, 32704, ..., 30016, 26240, 32928], dtype=uint16),
#   array([31552, 32736, 32960, ..., 32320, 35168, 32896], dtype=uint16),
#   array([34528, 29440, 33984, ..., 34272, 35648, 30528], dtype=uint16),
#   array([34208, 32128, 32544, ..., 33248, 33312, 34048], dtype=uint16),
#   array([30880, 31360, 34496, ..., 33216, 31840, 31616], dtype=uint16),
#   array([32032, 33248, 34144, ..., 32768, 30816, 28544], dtype=uint16),
#   array([29920, 29472, 31936, ..., 27392, 30848, 33536], dtype=uint16),
#   array([36064, 36000, 34144, ..., 35104, 31168, 31552], dtype=uint16),
#   array([38816, 35616, 37152, ..., 29632, 34016, 35488], dtype=uint16),
#   array([34880, 30656, 32032, ..., 28480, 35360, 34720], dtype=uint16),
#   array([33664, 35392, 36448, ..., 31712, 31872, 31968], dtype=uint16),
#   array([39008, 38176, 37056, ..., 34976, 36256, 36544], dtype=uint16),
#   array([36320, 33760, 32544, ..., 36000, 35104, 34624], dtype=uint16),
#   array([35552, 40096, 39136, ..., 30944, 29728, 30880], dtype=uint16),
#   array([31552, 32224, 36032, ..., 33632, 32224, 33408], dtype=uint16),
#   array([38496, 39136, 36544, ..., 31232, 31552, 31840], dtype=uint16),
#   array([31808, 29216, 29088, ..., 32672, 34400, 34880], dtype=uint16),
#   array([30144, 34400, 34688, ..., 33248, 28416, 29120], dtype=uint16),
#   array([37440, 36672, 35936, ..., 34848, 32160, 35872], dtype=uint16),
#   array([37760, 33600, 32256, ..., 33696, 34432, 31648], dtype=uint16),
#   array([35840, 34144, 35776, ..., 34944, 34464, 34912], dtype=uint16),
#   array([36352, 35136, 34336, ..., 31104, 29760, 32096], dtype=uint16),
#   array([33088, 32544, 35360, ..., 34976, 31744, 31040], dtype=uint16),
#   array([36192, 34784, 32288, ..., 31360, 32928, 34208], dtype=uint16),
#   array([33504, 32864, 32256, ..., 28960, 27296, 31520], dtype=uint16),
#   array([34464, 36576, 38144, ..., 32096, 31872, 30080], dtype=uint16),
#   array([33760, 31552, 34432, ..., 33216, 36064, 33888], dtype=uint16),
#   array([32576, 31360, 33376, ..., 32224, 34048, 31552], dtype=uint16),
#   array([35328, 34272, 33248, ..., 34080, 34080, 34144], dtype=uint16),
#   array([33184, 34400, 33920, ..., 31904, 29984, 28128], dtype=uint16),
#   array([34016, 35200, 35136, ..., 34688, 33856, 31200], dtype=uint16),
#   array([29760, 31328, 30144, ..., 35648, 34208, 35456], dtype=uint16),
#   array([35808, 36512, 34912, ..., 34944, 34944, 34816], dtype=uint16),
#   array([33824, 34304, 35488, ..., 34272, 33984, 34176], dtype=uint16),
#   array([35872, 34976, 35392, ..., 32192, 33536, 31776], dtype=uint16),
#   array([32672, 30304, 29568, ..., 35328, 35840, 36128], dtype=uint16),
#   array([31616, 33248, 34240, ..., 29920, 27776, 28960], dtype=uint16),
#   array([34016, 35968, 35424, ..., 34272, 34912, 36288], dtype=uint16),
#   array([36064, 32288, 32960, ..., 27904, 30080, 32352], dtype=uint16),
#   array([32416, 31296, 29088, ..., 34112, 35136, 32352], dtype=uint16),
#   array([34528, 34560, 32928, ..., 33984, 29856, 29696], dtype=uint16),
#   array([30560, 36320, 34208, ..., 36256, 33856, 34400], dtype=uint16),
#   array([34080, 36864, 36000, ..., 33632, 31872, 30048], dtype=uint16),
#   array([34144, 36096, 35840, ..., 33728, 33632, 31808], dtype=uint16),
#   array([32480, 34784, 32832, ..., 36800, 37056, 34656], dtype=uint16),
#   array([36672, 36224, 36864, ..., 32672, 33984, 29152], dtype=uint16),
#   array([36832, 34400, 33504, ..., 34752, 36256, 36800], dtype=uint16),
#   array([34304, 32192, 34688, ..., 33888, 33184, 33248], dtype=uint16),
#   array([32096, 34816, 34368, ..., 29088, 31040, 33472], dtype=uint16),
#   array([31168, 27936, 33632, ..., 36096, 34976, 34272], dtype=uint16),
#   array([35424, 33984, 34240, ..., 31328, 32512, 32192], dtype=uint16),
#   array([32832, 32288, 34080, ..., 33728, 33280, 34688], dtype=uint16),
#   array([31232, 34784, 32800, ..., 32576, 32384, 35712], dtype=uint16),
#   array([34880, 33376, 36064, ..., 29088, 36800, 32224], dtype=uint16),
#   array([33344, 34144, 37056, ..., 35232, 35232, 33024], dtype=uint16),
#   array([31424, 27712, 30048, ..., 31520, 32640, 35040], dtype=uint16),
#   array([35008, 34048, 35200, ..., 33184, 30144, 32608], dtype=uint16),
#   array([34048, 35392, 34976, ..., 34592, 36064, 34496], dtype=uint16),
#   array([35776, 35936, 37664, ..., 31456, 31680, 34432], dtype=uint16),
#   array([27456, 29440, 33120, ..., 35104, 33536, 33792], dtype=uint16),
#   array([33152, 34304, 32864, ..., 32192, 34368, 34752], dtype=uint16),
#   array([34016, 34080, 34464, ..., 32640, 31616, 33088], dtype=uint16),
#   array([35616, 31104, 33792, ..., 29280, 30624, 28352], dtype=uint16),
#   array([35008, 31712, 30240, ..., 34208, 34304, 33312], dtype=uint16),
#   array([35936, 34752, 35712, ..., 34656, 33312, 32896], dtype=uint16),
#   array([34752, 32672, 31136, ..., 34240, 35584, 35552], dtype=uint16),
#   array([35264, 32224, 32224, ..., 30944, 29632, 32960], dtype=uint16),
#   array([32192, 31552, 31296, ..., 30848, 32192, 33376], dtype=uint16),
#   array([28736, 38688, 34816, ..., 35680, 33312, 34304], dtype=uint16),
#   array([33408, 32128, 32864, ..., 32448, 32512, 35072], dtype=uint16),
#   array([38432, 34496, 33504, ..., 29600, 33888, 37056], dtype=uint16),
#   array([34912, 34112, 31904, ..., 30624, 30912, 33760], dtype=uint16),
#   array([33280, 34240, 34848, ..., 32576, 27456, 32032], dtype=uint16),
#   array([30880, 29088, 33024, ..., 36992, 36736, 35904], dtype=uint16),
#   array([32384, 32320, 33728, ..., 34912, 33952, 34336], dtype=uint16),
#   array([34752, 32544, 33184, ..., 33664, 34368, 34272], dtype=uint16),
#   array([34112, 35328, 34112, ..., 40864, 37536, 34368], dtype=uint16),
#   array([34912, 33056, 34176, ..., 31680, 28832, 28352], dtype=uint16),
#   array([30304, 34560, 33824, ..., 29120, 34304, 35648], dtype=uint16),
#   array([36832, 32128, 32384, ..., 26592, 26432, 27936], dtype=uint16),
#   array([33696, 36736, 35616, ..., 30688, 28960, 32448], dtype=uint16),
#   array([30944, 33216, 33824, ..., 31392, 35808, 32544], dtype=uint16),
#   array([30624, 30336, 33984, ..., 30688, 32736, 33280], dtype=uint16),
#   array([30624, 31584, 35392, ..., 31424, 33696, 36032], dtype=uint16),
#   array([34016, 33120, 33856, ..., 27360, 25664, 32576], dtype=uint16),
#   array([29888, 28736, 29568, ..., 33952, 33088, 31104], dtype=uint16),
#   array([27040, 32704, 31968, ..., 32864, 31488, 32160], dtype=uint16),
#   array([37760, 34144, 30816, ..., 33696, 35840, 39200], dtype=uint16),
#   array([34592, 36288, 37760, ..., 29664, 25248, 31904], dtype=uint16),
#   array([34528, 31136, 32512, ..., 34752, 35552, 34464], dtype=uint16),
#   array([32800, 34176, 35904, ..., 34912, 33760, 34976], dtype=uint16),
#   array([36224, 33568, 33504, ..., 26464, 27680, 32992], dtype=uint16),
#   array([24576, 27360, 36640, ..., 30944, 35840, 35104], dtype=uint16),
#   array([37344, 36096, 33856, ..., 33888, 36832, 33536], dtype=uint16),
#   array([34688, 32768, 29408, ..., 34752, 34400, 33568], dtype=uint16),
#   array([35328, 37152, 36672, ..., 35488, 35264, 29920], dtype=uint16),
#   array([35648, 32480, 34944, ..., 31840, 32928, 35680], dtype=uint16),
#   array([34464, 35232, 38752, ..., 31456, 35520, 34848], dtype=uint16),
#   array([33248, 34016, 35520, ..., 31904, 32416, 34144], dtype=uint16),
#   array([35520, 35520, 33664, ..., 35392, 34560, 33952], dtype=uint16),
#   array([38976, 34112, 30880, ..., 35744, 33600, 33408], dtype=uint16),
#   array([33248, 32960, 36672, ..., 33600, 31136, 33952], dtype=uint16),
#   array([37248, 33888, 33184, ..., 27200, 29600, 30080], dtype=uint16),
#   array([31488, 30752, 33664, ..., 33664, 34496, 34464], dtype=uint16),
#   array([39072, 32672, 28384, ..., 35840, 33088, 28352], dtype=uint16),
#   array([31552, 33856, 33376, ..., 35488, 38432, 36448], dtype=uint16),
#   array([30848, 29632, 31456, ..., 32704, 31072, 30016], dtype=uint16),
#   array([32672, 34400, 31968, ..., 30656, 30912, 29920], dtype=uint16),
#   array([32160, 30752, 30880, ..., 29856, 30720, 33184], dtype=uint16),
#   array([34528, 33248, 36096, ..., 32096, 30560, 33856], dtype=uint16),
#   array([38880, 36544, 35456, ..., 30016, 31744, 36640], dtype=uint16),
#   array([28192, 32928, 31168, ..., 33504, 33984, 29632], dtype=uint16),
#   array([32928, 32736, 32928, ..., 28640, 31104, 33536], dtype=uint16),
#   array([37344, 36512, 37120, ..., 34880, 35040, 35456], dtype=uint16),
#   array([33440, 35328, 35776, ..., 35872, 36800, 33856], dtype=uint16),
#   array([35104, 34976, 37568, ..., 29184, 33632, 36256], dtype=uint16),
#   array([31808, 32256, 34720, ..., 32160, 32768, 36928], dtype=uint16),
#   array([32896, 37152, 39200, ..., 30368, 31936, 32608], dtype=uint16),
#   array([33184, 30912, 27072, ..., 33408, 34688, 33600], dtype=uint16),
#   array([29152, 29888, 33280, ..., 30880, 28832, 32576], dtype=uint16),
#   array([34528, 35168, 35008, ..., 34144, 34240, 33120], dtype=uint16),
#   array([36480, 34816, 31968, ..., 35712, 32416, 30592], dtype=uint16),
#   array([35744, 35008, 34688, ..., 31424, 35264, 32192], dtype=uint16),
#   array([34912, 35296, 33120, ..., 30784, 28896, 28608], dtype=uint16),
#   array([32128, 32352, 33024, ..., 31616, 29888, 33696], dtype=uint16),
#   array([32704, 32160, 32704, ..., 32000, 29280, 32992], dtype=uint16),
#   array([32928, 33280, 33440, ..., 29568, 27008, 31712], dtype=uint16),
#   array([36832, 33920, 35392, ..., 33920, 30080, 28704], dtype=uint16),
#   array([31200, 32864, 34432, ..., 33216, 36192, 33344], dtype=uint16),
#   array([31200, 31232, 36032, ..., 33728, 32416, 29216], dtype=uint16),
#   array([33088, 30784, 28896, ..., 33536, 34656, 35232], dtype=uint16),
#   array([34592, 34496, 33120, ..., 32224, 28736, 27360], dtype=uint16),
#   array([34752, 32608, 32000, ..., 34304, 31808, 31200], dtype=uint16),
#   array([32736, 26080, 34304, ..., 36192, 35136, 33056], dtype=uint16),
#   array([35424, 35872, 34816, ..., 33952, 35008, 33280], dtype=uint16),
#   array([33600, 31648, 32736, ..., 34336, 34976, 32384], dtype=uint16),
#   array([34976, 33344, 31168, ..., 32480, 32288, 29600], dtype=uint16),
#   array([32352, 27712, 30432, ..., 33824, 35232, 38304], dtype=uint16),
#   array([31136, 33728, 33824, ..., 30720, 28288, 26272], dtype=uint16),
#   array([34144, 35232, 34528, ..., 33792, 34176, 35424], dtype=uint16),
#   array([33600, 34432, 31200, ..., 26336, 29024, 32416], dtype=uint16),
#   array([32480, 30304, 28512, ..., 35296, 33984, 32096], dtype=uint16),
#   array([33376, 32800, 31904, ..., 32256, 30816, 31744], dtype=uint16),
#   array([33312, 34464, 35520, ..., 35072, 33696, 33376], dtype=uint16),
#   array([36128, 33312, 36288, ..., 34208, 31616, 30208], dtype=uint16),
#   array([33376, 35104, 34208, ..., 32896, 32736, 32608], dtype=uint16),
#   array([32608, 33312, 33504, ..., 34720, 35840, 34016], dtype=uint16),
#   array([33824, 35712, 34848, ..., 33120, 31456, 28512], dtype=uint16),
#   array([32512, 34400, 34656, ..., 35392, 35136, 35776], dtype=uint16),
#   array([33056, 31104, 32096, ..., 32512, 32448, 32768], dtype=uint16),
#   array([32544, 33728, 33312, ..., 27904, 28640, 33440], dtype=uint16),
#   array([30080, 30144, 36064, ..., 36384, 35552, 33952], dtype=uint16),
#   array([34016, 33856, 34496, ..., 33056, 33152, 34368], dtype=uint16),
#   array([33184, 31456, 33184, ..., 34272, 31712, 32832], dtype=uint16),
#   array([33376, 31360, 29984, ..., 32096, 33856, 33952], dtype=uint16),
#   array([33056, 32928, 31104, ..., 29056, 34816, 33536], dtype=uint16),
#   array([33344, 36000, 32064, ..., 31648, 34944, 34016], dtype=uint16),
#   array([27040, 28512, 31040, ..., 31296, 31616, 34240], dtype=uint16),
#   array([34944, 34464, 33728, ..., 31616, 31008, 31872], dtype=uint16),
#   array([33504, 36064, 35136, ..., 33664, 34176, 34592], dtype=uint16),
#   array([34400, 34976, 36352, ..., 28512, 30976, 31904], dtype=uint16),
#   array([25728, 33152, 33024, ..., 34016, 31776, 33920], dtype=uint16),
#   array([34176, 34048, 31424, ..., 29920, 33984, 34624], dtype=uint16),
#   array([34208, 35104, 35840, ..., 33664, 32864, 30496], dtype=uint16),
#   array([35968, 34304, 33728, ..., 27552, 29280, 28480], dtype=uint16),
#   array([33696, 32000, 28096, ..., 35520, 31968, 33664], dtype=uint16),
#   array([33504, 35456, 33504, ..., 34592, 33856, 36384], dtype=uint16),
#   array([30016, 29568, 31968, ..., 31456, 33504, 32672], dtype=uint16),
#   array([32480, 33504, 34208, ..., 34304, 30784, 31712], dtype=uint16),
#   array([30432, 31840, 36416, ..., 30272, 29920, 31936], dtype=uint16),
#   array([30592, 38080, 34240, ..., 34400, 34144, 35296], dtype=uint16),
#   array([33376, 33920, 31360, ..., 34432, 33984, 33952], dtype=uint16),
#   array([34208, 31424, 31808, ..., 31136, 34432, 40160], dtype=uint16),
#   array([34496, 31296, 30048, ..., 32480, 32224, 34752], dtype=uint16),
#   array([35648, 37088, 37312, ..., 31264, 26752, 30592], dtype=uint16),
#   array([30368, 29152, 34592, ..., 39616, 36192, 35744], dtype=uint16),
#   array([30400, 32544, 35680, ..., 35360, 34624, 34336], dtype=uint16),
#   array([35136, 35648, 31072, ..., 33696, 33408, 32960], dtype=uint16),
#   array([33504, 31776, 33568, ..., 38752, 39520, 36192], dtype=uint16),
#   array([32672, 32192, 38368, ..., 33280, 30336, 28992], dtype=uint16),
#   array([32288, 29344, 31936, ..., 27360, 31104, 34784], dtype=uint16),
#   array([33280, 28928, 34144, ..., 27392, 26304, 27904], dtype=uint16),
#   array([37600, 37920, 34528, ..., 31616, 30432, 35712], dtype=uint16),
#   array([31360, 32736, 36992, ..., 31936, 33600, 32928], dtype=uint16),
#   array([30240, 29472, 34240, ..., 31680, 29888, 32320], dtype=uint16),
#   array([33600, 34720, 33792, ..., 32896, 37248, 38720], dtype=uint16),
#   array([32000, 32512, 38336, ..., 29920, 28256, 31008], dtype=uint16),
#   array([28960, 27872, 32480, ..., 35424, 33760, 30048], dtype=uint16),
#   array([27968, 30688, 33888, ..., 33408, 32768, 32192], dtype=uint16),
#   array([36736, 30464, 29856, ..., 31296, 33696, 36096], dtype=uint16),
#   array([34208, 35520, 34048, ..., 28608, 22816, 31808], dtype=uint16),
#   array([31968, 33984, 30912, ..., 32416, 35520, 36160], dtype=uint16),
#   array([32416, 33632, 35008, ..., 36544, 35616, 34528], dtype=uint16),
#   array([32512, 33280, 34976, ..., 30592, 32384, 31968], dtype=uint16),
#   array([23616, 30432, 32352, ..., 30944, 34112, 36416], dtype=uint16),
#   array([33984, 36384, 33888, ..., 35840, 37824, 33728], dtype=uint16),
#   array([35840, 29472, 30592, ..., 32832, 33440, 35456], dtype=uint16),
#   array([34976, 37056, 33472, ..., 35296, 33536, 30592], dtype=uint16),
#   array([34944, 35424, 29632, ..., 34496, 32736, 34496], dtype=uint16),
#   array([32448, 35584, 36832, ..., 31136, 35648, 37088], dtype=uint16),
#   array([33568, 33824, 32512, ..., 30816, 32608, 33632], dtype=uint16),
#   array([34944, 32832, 32000, ..., 36512, 35616, 35936], dtype=uint16),
#   array([32608, 29760, 32288, ..., 35264, 33888, 32960], dtype=uint16),
#   array([33312, 33152, 37600, ..., 34784, 34976, 34272], dtype=uint16),
#   array([33376, 34112, 31360, ..., 25696, 30144, 33696], dtype=uint16),
#   array([35488, 31040, 32704, ..., 32864, 33024, 33728], dtype=uint16),
#   array([36768, 29408, 30016, ..., 35936, 33952, 28992], dtype=uint16),
#   array([31072, 33792, 34080, ..., 37312, 36256, 33600], dtype=uint16),
#   array([31104, 29312, 32736, ..., 32352, 31424, 29792], dtype=uint16),
#   array([31808, 30720, 32448, ..., 32672, 28512, 28416], dtype=uint16),
#   array([33920, 29536, 26528, ..., 28768, 29472, 32736], dtype=uint16),
#   array([36704, 34784, 35520, ..., 31328, 32256, 35040], dtype=uint16),
#   array([36576, 34656, 34240, ..., 28864, 30400, 36000], dtype=uint16),
#   array([30688, 32704, 34752, ..., 32320, 31808, 28384], dtype=uint16),
#   array([32000, 32608, 34976, ..., 28608, 30624, 33664], dtype=uint16),
#   array([35872, 37632, 36480, ..., 35968, 34432, 35712], dtype=uint16),
#   array([33632, 33888, 32064, ..., 35264, 35680, 34592], dtype=uint16),
#   array([34880, 33856, 34848, ..., 31264, 32544, 32640], dtype=uint16),
#   array([29312, 30944, 32128, ..., 30720, 32832, 35616], dtype=uint16),
#   array([35424, 38304, 34240, ..., 31744, 32992, 31072], dtype=uint16),
#   array([34144, 28512, 28480, ..., 34208, 34240, 34720], dtype=uint16),
#   array([28672, 31648, 33984, ..., 31424, 25984, 32800], dtype=uint16),
#   array([36448, 36256, 38656, ..., 32832, 34976, 32512], dtype=uint16),
#   array([37728, 31392, 31648, ..., 33568, 32992, 30176], dtype=uint16),
#   array([35168, 34720, 33920, ..., 31104, 34976, 33280], dtype=uint16),
#   array([33728, 34688, 34208, ..., 29664, 29472, 30752], dtype=uint16),
#   array([31520, 32768, 34144, ..., 32096, 31136, 32864], dtype=uint16),
#   array([35552, 34880, 32160, ..., 31552, 31616, 33600], dtype=uint16),
#   array([32672, 35104, 32224, ..., 25664, 26784, 31200], dtype=uint16),
#   array([35936, 34464, 36512, ..., 32544, 27392, 26656], dtype=uint16),
#   array([32992, 31200, 33824, ..., 35328, 34016, 34304], dtype=uint16),
#   array([29760, 31264, 35552, ..., 32672, 32096, 30144], dtype=uint16),
#   array([32992, 31648, 30784, ..., 33536, 34272, 33248], dtype=uint16),
#   array([33344, 35328, 33952, ..., 29024, 25600, 30208], dtype=uint16),
#   array([34240, 33056, 32384, ..., 32768, 30784, 31072], dtype=uint16),
#   array([32896, 27552, 34880, ..., 34976, 34112, 35296], dtype=uint16),
#   array([35424, 35296, 33504, ..., 35968, 34528, 31328], dtype=uint16),
#   array([34048, 31584, 32608, ..., 31008, 33504, 32928], dtype=uint16),
#   array([35040, 34560, 32352, ..., 35328, 30720, 29344], dtype=uint16),
#   array([32576, 28224, 32128, ..., 35712, 35840, 35904], dtype=uint16),
#   array([31296, 35104, 34208, ..., 30112, 24864, 28992], dtype=uint16),
#   array([35904, 36416, 34112, ..., 33824, 33824, 34048], dtype=uint16),
#   array([34336, 32704, 32192, ..., 23392, 30144, 31680], dtype=uint16),
#   array([32608, 30016, 27712, ..., 34688, 33696, 33120], dtype=uint16),
#   array([32992, 33536, 31712, ..., 31136, 30272, 29376], dtype=uint16),
#   array([33472, 34720, 35648, ..., 33984, 37600, 31200], dtype=uint16),
#   array([35648, 33184, 35168, ..., 31520, 30720, 31776], dtype=uint16),
#   array([33120, 32864, 34592, ..., 33120, 31936, 30432], dtype=uint16),
#   array([34912, 31840, 33120, ..., 36704, 37344, 37632], dtype=uint16),
#   array([37024, 38048, 35104, ..., 33504, 31136, 28256], dtype=uint16),
#   array([35296, 35872, 32096, ..., 34496, 35168, 34656], dtype=uint16),
#   array([32992, 33600, 33056, ..., 31776, 34464, 32192], dtype=uint16),
#   array([32640, 33664, 32192, ..., 28832, 33152, 32352], dtype=uint16),
#   array([29760, 31584, 34368, ..., 34176, 33792, 34368], dtype=uint16),
#   array([32224, 33760, 35168, ..., 32384, 32064, 35104], dtype=uint16),
#   array([31552, 33408, 33184, ..., 35872, 34016, 33408], dtype=uint16),
#   array([34688, 32992, 31552, ..., 31936, 33248, 34016], dtype=uint16),
#   array([34240, 33344, 33536, ..., 32608, 33216, 33024], dtype=uint16),
#   array([34912, 33824, 30208, ..., 35840, 35744, 34176], dtype=uint16),
#   array([27456, 28256, 32928, ..., 33568, 34240, 33888], dtype=uint16),
#   array([36128, 33184, 34368, ..., 29408, 32480, 32352], dtype=uint16),
#   array([34144, 34240, 36064, ..., 33536, 35456, 32000], dtype=uint16),
#   array([35008, 35968, 36480, ..., 29952, 31456, 33152], dtype=uint16),
#   array([26848, 33536, 32992, ..., 32288, 32128, 32096], dtype=uint16),
#   array([33824, 35424, 33536, ..., 33440, 34560, 34304], dtype=uint16),
#   array([35136, 33216, 34560, ..., 31200, 34368, 32352], dtype=uint16),
#   array([36672, 32992, 34016, ..., 24736, 31616, 31680], dtype=uint16),
#   array([31968, 30240, 31008, ..., 31968, 33056, 34752], dtype=uint16),
#   array([33088, 32224, 34080, ..., 33344, 36032, 35904], dtype=uint16),
#   array([30144, 29888, 29888, ..., 33376, 35264, 34304], dtype=uint16),
#   array([34240, 34304, 36128, ..., 32864, 33312, 30272], dtype=uint16),
#   array([30176, 32224, 37856, ..., 31200, 29344, 32704], dtype=uint16),
#   array([32576, 39232, 34528, ..., 34336, 34592, 33408], dtype=uint16),
#   array([33024, 34112, 32480, ..., 34336, 34592, 35392], dtype=uint16),
#   array([34976, 32256, 31200, ..., 33696, 35200, 38048], dtype=uint16),
#   array([31904, 29056, 31648, ..., 33536, 33056, 34080], dtype=uint16),
#   array([34336, 35616, 36000, ..., 27872, 28576, 29472], dtype=uint16),
#   array([31520, 27936, 33632, ..., 33440, 36640, 34400], dtype=uint16),
#   array([32128, 33888, 34176, ..., 35520, 33984, 31840], dtype=uint16),
#   array([35008, 34816, 33504, ..., 29888, 32416, 31616], dtype=uint16),
#   array([34240, 34112, 34144, ..., 37728, 36704, 34560], dtype=uint16),
#   array([31296, 30368, 39648, ..., 31040, 30112, 32416], dtype=uint16),
#   array([32544, 29408, 31424, ..., 30240, 33536, 36160], dtype=uint16),
#   array([33376, 30144, 33632, ..., 30176, 29472, 30496], dtype=uint16),
#   array([37184, 36896, 32544, ..., 32032, 32640, 34624], dtype=uint16),
#   array([34176, 34144, 36704, ..., 34240, 33536, 33408], dtype=uint16),
#   array([33760, 31648, 30528, ..., 29184, 29440, 32448], dtype=uint16),
#   array([37440, 37152, 34656, ..., 31520, 38656, 37344], dtype=uint16),
#   array([31296, 30688, 34368, ..., 30272, 28320, 31680], dtype=uint16),
#   array([26368, 26080, 33056, ..., 34240, 32800, 30976], dtype=uint16),
#   array([32256, 29248, 29568, ..., 31296, 33408, 31456], dtype=uint16),
#   array([35136, 30080, 31488, ..., 32416, 33568, 34400], dtype=uint16),
#   array([36704, 34208, 30112, ..., 20160, 24000, 32480], dtype=uint16),
#   array([32576, 33184, 35776, ..., 34112, 34592, 36448], dtype=uint16),
#   array([34592, 34272, 35904, ..., 33344, 35456, 29952], dtype=uint16),
#   array([29344, 34592, 36896, ..., 28448, 34016, 29984], dtype=uint16),
#   array([24992, 30176, 32320, ..., 31872, 33344, 34144], dtype=uint16),
#   array([36736, 36832, 33632, ..., 35072, 35936, 37120], dtype=uint16),
#   array([36448, 32576, 33664, ..., 34144, 36448, 35328], dtype=uint16),
#   array([35296, 36992, 30912, ..., 36672, 35712, 36224], dtype=uint16),
#   array([34560, 33888, 30208, ..., 31488, 34368, 31776], dtype=uint16),
#   array([30336, 36576, 39456, ..., 31744, 33056, 35328], dtype=uint16),
#   array([36608, 29152, 33440, ..., 31264, 32832, 33440], dtype=uint16),
#   array([31904, 29760, 31136, ..., 33632, 36896, 35616], dtype=uint16),
#   array([32288, 31328, 34624, ..., 33472, 32800, 31296], dtype=uint16),
#   array([36416, 33184, 36512, ..., 30976, 35232, 32704], dtype=uint16),
#   array([32032, 34528, 30400, ..., 24320, 34048, 30624], dtype=uint16),
#   array([34336, 33216, 31104, ..., 34080, 33472, 32896], dtype=uint16),
#   array([34784, 30144, 31392, ..., 34496, 33088, 28768], dtype=uint16),
#   array([31616, 34144, 32000, ..., 35808, 31456, 31232], dtype=uint16),
#   array([29472, 29536, 33120, ..., 29248, 32896, 32672], dtype=uint16),
#   array([31296, 32256, 31168, ..., 33152, 27616, 27968], dtype=uint16),
#   array([32448, 30176, 28384, ..., 29344, 29408, 30240], dtype=uint16),
#   array([35296, 35264, 33696, ..., 31392, 32288, 35232], dtype=uint16),
#   array([34176, 35552, 36608, ..., 29440, 32352, 35488], dtype=uint16),
#   array([33120, 35328, 33728, ..., 31296, 30400, 26016], dtype=uint16),
#   array([34656, 34880, 36000, ..., 29184, 32736, 31616], dtype=uint16),
#   array([39040, 37024, 36000, ..., 36032, 37376, 34400], dtype=uint16),
#   array([35520, 34816, 33216, ..., 34816, 33344, 35008], dtype=uint16),
#   array([33664, 36416, 34656, ..., 30816, 29472, 31712], dtype=uint16),
#   array([32608, 31680, 33696, ..., 30624, 33440, 32768], dtype=uint16),
#   array([37120, 37920, 35936, ..., 29344, 30688, 31200], dtype=uint16),
#   array([33536, 29600, 28224, ..., 34432, 33984, 33472], dtype=uint16),
#   array([27552, 30816, 31872, ..., 27936, 27424, 34592], dtype=uint16),
#   array([35552, 37536, 38336, ..., 32864, 33696, 32288], dtype=uint16),
#   array([35680, 33312, 30560, ..., 32032, 31680, 32768], dtype=uint16),
#   array([35744, 37088, 34528, ..., 33856, 32384, 35168], dtype=uint16),
#   array([36064, 35392, 36512, ..., 31168, 32096, 30944], dtype=uint16),
#   array([34176, 35744, 32992, ..., 33696, 31584, 31424], dtype=uint16),
#   array([35264, 34400, 31200, ..., 32640, 32704, 32608], dtype=uint16),
#   array([33344, 34912, 33984, ..., 31232, 28160, 29408], dtype=uint16),
#   array([37184, 36768, 36896, ..., 35040, 32640, 28704], dtype=uint16),
#   array([31584, 33920, 36512, ..., 33568, 35488, 33632], dtype=uint16),
#   array([29952, 33984, 33920, ..., 34176, 34176, 31392], dtype=uint16),
#   array([35136, 32064, 33472, ..., 32064, 33696, 33600], dtype=uint16),
#   array([34912, 33888, 33920, ..., 31904, 32896, 28736], dtype=uint16),
#   array([33088, 35552, 33216, ..., 33536, 33536, 29248], dtype=uint16),
#   array([30272, 31072, 33856, ..., 34016, 35648, 32640], dtype=uint16),
#   array([38880, 36096, 37216, ..., 34720, 36128, 35008], dtype=uint16),
#   array([34720, 33760, 34912, ..., 32768, 32672, 35808], dtype=uint16),
#   array([33952, 35232, 33824, ..., 33728, 33664, 32224], dtype=uint16),
#   array([30464, 29984, 34336, ..., 34016, 34112, 33920], dtype=uint16),
#   array([35136, 33216, 34112, ..., 33856, 32032, 25664], dtype=uint16),
#   array([36064, 36288, 35968, ..., 33792, 33920, 34336], dtype=uint16),
#   array([34816, 34944, 32672, ..., 31392, 26496, 34048], dtype=uint16),
#   array([33760, 28928, 28992, ..., 36128, 34592, 34336], dtype=uint16),
#   array([34784, 34752, 35360, ..., 34400, 34880, 31168], dtype=uint16),
#   array([36096, 34272, 34336, ..., 36864, 33152, 35456], dtype=uint16),
#   array([37600, 36192, 34400, ..., 34496, 31040, 30304], dtype=uint16),
#   array([36896, 34080, 36544, ..., 35104, 34656, 33088], dtype=uint16),
#   array([35232, 33440, 34080, ..., 35680, 35424, 34272], dtype=uint16),
#   array([36320, 35392, 35264, ..., 34560, 32480, 34144], dtype=uint16),
#   array([35648, 35616, 34496, ..., 35104, 35296, 36128], dtype=uint16),
#   array([33856, 33504, 34240, ..., 34592, 31520, 33792], dtype=uint16),
#   array([33984, 34912, 32160, ..., 34016, 27008, 32800], dtype=uint16),
#   array([29568, 33408, 33760, ..., 34848, 34688, 34240], dtype=uint16),
#   array([36608, 36800, 35232, ..., 31552, 33344, 33376], dtype=uint16),
#   array([33824, 34688, 34240, ..., 33440, 32864, 31904], dtype=uint16),
#   array([33984, 30784, 29280, ..., 31328, 33088, 32480], dtype=uint16),
#   array([33856, 33568, 32128, ..., 30336, 31360, 35552], dtype=uint16),
#   array([36768, 35712, 32256, ..., 35872, 34688, 36160], dtype=uint16),
#   array([27968, 31328, 34144, ..., 32064, 32512, 34400], dtype=uint16),
#   array([35168, 37248, 35360, ..., 35520, 30336, 34656], dtype=uint16),
#   array([35360, 35712, 38464, ..., 32896, 33696, 33536], dtype=uint16),
#   array([35488, 35904, 36704, ..., 30144, 31936, 30848], dtype=uint16),
#   array([30912, 34752, 34208, ..., 31936, 33248, 31328], dtype=uint16),
#   array([34368, 35392, 33888, ..., 30240, 34240, 33952], dtype=uint16),
#   array([37056, 32992, 36352, ..., 32800, 32896, 34080], dtype=uint16),
#   array([33504, 35680, 34528, ..., 29344, 27872, 33120], dtype=uint16),
#   array([33920, 31264, 35168, ..., 37504, 33184, 31648], dtype=uint16),
#   array([32800, 36128, 33600, ..., 32256, 34496, 36160], dtype=uint16),
#   array([30656, 31488, 33920, ..., 35040, 34688, 36736], dtype=uint16),
#   array([32512, 36096, 35488, ..., 33920, 32672, 33504], dtype=uint16),
#   array([33824, 35328, 35968, ..., 37024, 34944, 32832], dtype=uint16),
#   array([35552, 34912, 34336, ..., 32672, 33280, 33056], dtype=uint16),
#   array([32864, 33376, 34688, ..., 36544, 37472, 36832], dtype=uint16),
#   array([37312, 36128, 36128, ..., 32416, 34016, 34368], dtype=uint16),
#   array([33856, 32800, 32672, ..., 33216, 33760, 31968], dtype=uint16),
#   array([36608, 36000, 34752, ..., 34880, 29856, 30336], dtype=uint16),
#   array([29344, 33216, 34336, ..., 29728, 31104, 37408], dtype=uint16),
#   array([33312, 35648, 35936, ..., 35264, 36512, 36320], dtype=uint16),
#   array([33440, 35392, 33920, ..., 33856, 33824, 32128], dtype=uint16),
#   array([33824, 36000, 36992, ..., 32352, 36704, 39232], dtype=uint16),
#   array([32608, 34592, 39520, ..., 35936, 31776, 31744], dtype=uint16),
#   array([34432, 34880, 32448, ..., 33920, 31520, 30912], dtype=uint16),
#   array([29408, 29984, 34176, ..., 31232, 33504, 32512], dtype=uint16),
#   array([36384, 34464, 33792, ..., 35648, 32608, 33664], dtype=uint16),
#   array([34816, 36000, 35232, ..., 31648, 35520, 33920], dtype=uint16),
#   array([30272, 34240, 31616, ..., 33184, 31360, 30336], dtype=uint16),
#   array([38080, 36768, 35264, ..., 32096, 30656, 39040], dtype=uint16),
#   array([32448, 33408, 38688, ..., 30720, 31392, 30144], dtype=uint16),
#   array([27776, 29600, 35744, ..., 37728, 34656, 33152], dtype=uint16),
#   array([31104, 28768, 32448, ..., 35776, 31264, 31872], dtype=uint16),
#   array([31232, 32416, 35456, ..., 31552, 31520, 31040], dtype=uint16),
#   array([36864, 34848, 30720, ..., 30976, 23360, 27104], dtype=uint16),
#   array([35136, 36288, 35456, ..., 33120, 32160, 35136], dtype=uint16),
#   array([35296, 36320, 33472, ..., 33696, 33504, 37408], dtype=uint16),
#   array([32320, 34144, 38688, ..., 35360, 28416, 33440], dtype=uint16),
#   array([28832, 34720, 33248, ..., 32256, 32992, 33312], dtype=uint16),
#   array([38272, 38624, 33920, ..., 35840, 38944, 35488], dtype=uint16),
#   array([35008, 32224, 32704, ..., 35168, 33088, 37728], dtype=uint16),
#   array([38080, 36480, 32896, ..., 33632, 34304, 35648], dtype=uint16),
#   array([36704, 36736, 32576, ..., 32416, 33056, 30336], dtype=uint16),
#   array([35744, 37952, 36160, ..., 32576, 32416, 29984], dtype=uint16),
#   array([34720, 35680, 31520, ..., 33536, 33216, 31840], dtype=uint16),
#   array([33792, 33248, 32864, ..., 32672, 33056, 37120], dtype=uint16),
#   array([33792, 34560, 37376, ..., 34112, 34624, 34528], dtype=uint16),
#   array([33472, 36512, 37376, ..., 34912, 31680, 37440], dtype=uint16),
#   array([34784, 32736, 34400, ..., 26368, 25312, 34528], dtype=uint16),
#   array([32800, 35232, 33280, ..., 33440, 35264, 32672], dtype=uint16),
#   array([33152, 30368, 33184, ..., 35168, 32800, 32672], dtype=uint16),
#   array([34400, 32256, 32544, ..., 37216, 34016, 30944], dtype=uint16),
#   array([29280, 33088, 36864, ..., 30176, 31168, 34432], dtype=uint16),
#   array([33280, 33088, 33760, ..., 31456, 33824, 32288], dtype=uint16),
#   array([30112, 31616, 30976, ..., 27168, 28256, 30944], dtype=uint16),
#   array([36704, 37248, 34368, ..., 34208, 33632, 31456], dtype=uint16),
#   array([35552, 37760, 38048, ..., 29248, 30432, 32896], dtype=uint16),
#   array([37696, 34016, 32640, ..., 29952, 32096, 33280], dtype=uint16),
#   array([35040, 34976, 34848, ..., 28704, 32224, 32288], dtype=uint16),
#   array([38784, 39776, 37408, ..., 36192, 36032, 34592], dtype=uint16),
#   array([37440, 34720, 32096, ..., 34144, 33984, 33216], dtype=uint16),
#   array([36288, 35904, 38400, ..., 33344, 33088, 29472], dtype=uint16),
#   array([32608, 33600, 35616, ..., 34880, 32416, 35360], dtype=uint16),
#   array([38016, 39072, 34848, ..., 30528, 29312, 32448], dtype=uint16),
#   array([33824, 27904, 30208, ..., 31680, 34784, 35904], dtype=uint16),
#   array([29792, 33824, 33952, ..., 32672, 30112, 28384], dtype=uint16),
#   array([37600, 36160, 37696, ..., 33472, 34080, 33024], dtype=uint16),
#   array([37440, 34016, 31488, ..., 32448, 34144, 30464], dtype=uint16),
#   array([34912, 35520, 35840, ..., 32416, 35360, 34848], dtype=uint16),
#   array([35968, 33760, 34656, ..., 30720, 30400, 32800], dtype=uint16),
#   array([34176, 31424, 33824, ..., 33184, 31520, 32608], dtype=uint16),
#   array([36448, 34624, 32128, ..., 32128, 33856, 33600], dtype=uint16),
#   array([33504, 32800, 33600, ..., 27456, 26848, 31328], dtype=uint16),
#   array([35328, 36672, 36064, ..., 33696, 30304, 29888], dtype=uint16),
#   array([34048, 31648, 33888, ..., 34496, 35616, 34080], dtype=uint16),
#   array([33088, 29312, 31680, ..., 32320, 34304, 30464], dtype=uint16),
#   array([34400, 36608, 32672, ..., 34656, 32800, 33440], dtype=uint16),
#   array([34016, 31776, 34944, ..., 32064, 29792, 29728], dtype=uint16),
#   array([34816, 33536, 32352, ..., 35328, 32608, 30656], dtype=uint16),
#   array([29408, 27456, 29856, ..., 34944, 33984, 35200], dtype=uint16),
#   array([35904, 35392, 34208, ..., 37888, 36096, 31584], dtype=uint16),
#   array([32352, 34976, 33120, ..., 33248, 34880, 34368], dtype=uint16),
#   array([34848, 33696, 34528, ..., 33248, 33632, 30464], dtype=uint16),
#   array([34688, 30496, 27424, ..., 34688, 37408, 36832], dtype=uint16),
#   array([32224, 33792, 33888, ..., 32672, 29568, 28800], dtype=uint16),
#   array([34976, 34080, 35840, ..., 33792, 33504, 36064], dtype=uint16),
#   array([33696, 35040, 33760, ..., 28608, 28800, 33184], dtype=uint16),
#   array([31008, 31808, 28992, ..., 33280, 34528, 31968], dtype=uint16),
#   array([33824, 32160, 32576, ..., 30368, 31872, 31872], dtype=uint16),
#   array([32320, 36512, 34048, ..., 35776, 32416, 35968], dtype=uint16),
#   array([30112, 37600, 34688, ..., 32640, 31072, 32640], dtype=uint16),
#   array([33472, 34880, 35456, ..., 34784, 34208, 31744], dtype=uint16),
#   array([33280, 34336, 33056, ..., 35712, 36320, 33856], dtype=uint16),
#   array([35776, 34688, 34048, ..., 31776, 33280, 32128], dtype=uint16),
#   array([34688, 35232, 35072, ..., 34656, 34688, 35648], dtype=uint16),
#   array([34944, 31232, 31360, ..., 34336, 32800, 33152], dtype=uint16),
#   array([34976, 32736, 33216, ..., 27104, 28672, 32768], dtype=uint16),
#   array([30400, 28576, 32768, ..., 34816, 35808, 35488], dtype=uint16),
#   array([35488, 34656, 34208, ..., 34752, 32544, 33728], dtype=uint16),
#   array([32512, 32352, 32992, ..., 32480, 34624, 35360], dtype=uint16),
#   array([32320, 33664, 33024, ..., 31232, 34528, 34176], dtype=uint16),
#   array([36192, 32896, 36384, ..., 29664, 34848, 33280], dtype=uint16),
#   array([33312, 35168, 33504, ..., 33856, 32384, 34112], dtype=uint16),
#   array([33056, 27744, 31168, ..., 32160, 34240, 33984], dtype=uint16),
#   array([35680, 34400, 35680, ..., 32096, 30464, 34624], dtype=uint16),
#   array([33280, 37024, 35584, ..., 34336, 33664, 34176], dtype=uint16),
#   array([35840, 33792, 35392, ..., 29728, 32608, 31776], dtype=uint16),
#   array([27968, 28768, 32512, ..., 32672, 32704, 32448], dtype=uint16),
#   array([32992, 32512, 34048, ..., 31264, 35072, 33824], dtype=uint16),
#   array([34400, 35488, 33760, ..., 33440, 30240, 31968], dtype=uint16),
#   array([34848, 33184, 32160, ..., 27168, 30496, 30144], dtype=uint16),
#   array([27264, 30144, 33248, ..., 35968, 32800, 31296], dtype=uint16),
#   array([35424, 33184, 33280, ..., 35520, 37376, 35488], dtype=uint16),
#   array([31648, 30144, 30048, ..., 34912, 34336, 34176], dtype=uint16),
#   array([33184, 32896, 35712, ..., 29888, 33472, 35008], dtype=uint16),
#   array([33056, 36032, 34912, ..., 34912, 36512, 36224], dtype=uint16),
#   array([27232, 33568, 34688, ..., 32096, 33312, 35296], dtype=uint16),
#   array([34496, 31968, 31136, ..., 38144, 38048, 34656], dtype=uint16),
#   array([33600, 35552, 36032, ..., 32320, 34144, 32960], dtype=uint16),
#   array([36064, 36544, 33184, ..., 33920, 34304, 32288], dtype=uint16),
#   array([36128, 37248, 35872, ..., 35040, 25216, 33024], dtype=uint16),
#   array([35968, 34816, 34784, ..., 32864, 31392, 36352], dtype=uint16),
# ...
#   array([33728, 31712, 34880, ..., 30560, 29248, 32768], dtype=uint16),
#   array([27264, 26368, 33184, ..., 37248, 37568, 34912], dtype=uint16),
#   array([29664, 30976, 32224, ..., 30944, 32256, 34144], dtype=uint16),
#   array([37120, 28864, 29888, ..., 30336, 29632, 36224], dtype=uint16),
#   array([37440, 36640, 35552, ..., 28096, 20736, 28832], dtype=uint16),
#   array([36768, 35328, 32928, ..., 34400, 33504, 32000], dtype=uint16),
#   array([37312, 33248, 31872, ..., 29952, 29504, 36000], dtype=uint16),
#   array([30496, 30912, 34496, ..., 27680, 28832, 33376], dtype=uint16),
#   array([24928, 31392, 31936, ..., 33312, 35936, 37248], dtype=uint16),
#   array([32224, 36128, 36096, ..., 32704, 36352, 34144], dtype=uint16),
#   array([35936, 29088, 33216, ..., 34752, 35616, 36160], dtype=uint16),
#   array([34496, 38368, 30912, ..., 35168, 32352, 29152], dtype=uint16),
#   array([33088, 36768, 36192, ..., 34208, 33568, 34784], dtype=uint16),
#   array([39680, 35552, 33760, ..., 31584, 33440, 31776], dtype=uint16),
#   array([35520, 30048, 35072, ..., 31936, 33984, 36736], dtype=uint16),
#   array([33472, 34880, 32832, ..., 34560, 36256, 32736], dtype=uint16),
#   array([34432, 30336, 32832, ..., 34912, 34272, 34592], dtype=uint16),
#   array([30400, 33408, 37408, ..., 33440, 34048, 34336], dtype=uint16),
#   array([32032, 36192, 31520, ..., 25760, 29856, 36128], dtype=uint16),
#   array([35232, 31136, 32608, ..., 34272, 35552, 34592], dtype=uint16),
#   array([37184, 26688, 28864, ..., 34464, 32576, 32096], dtype=uint16),
#   array([33152, 33280, 31648, ..., 33216, 33664, 33408], dtype=uint16),
#   array([27904, 34208, 33376, ..., 31808, 33440, 33120], dtype=uint16),
#   array([34304, 33472, 35840, ..., 33952, 34848, 30656], dtype=uint16),
#   array([29440, 28032, 29056, ..., 28864, 30336, 32096], dtype=uint16),
#   array([36064, 33952, 35968, ..., 32448, 34016, 33152], dtype=uint16),
#   array([35328, 37984, 38464, ..., 32032, 30016, 37024], dtype=uint16),
#   array([33856, 33024, 31424, ..., 28192, 31200, 29312], dtype=uint16),
#   array([33472, 34144, 35424, ..., 29760, 30336, 34208], dtype=uint16),
#   array([37152, 36128, 35712, ..., 34464, 36384, 35488], dtype=uint16),
#   array([33888, 34912, 34272, ..., 35744, 34656, 32544], dtype=uint16),
#   array([35840, 35552, 37728, ..., 29824, 30976, 30752], dtype=uint16),
#   array([31552, 31008, 33536, ..., 30240, 31232, 36704], dtype=uint16),
#   array([36704, 37600, 34592, ..., 32000, 31392, 32448], dtype=uint16),
#   array([33696, 29696, 26592, ..., 33024, 32256, 34688], dtype=uint16),
#   array([26976, 32160, 33536, ..., 30336, 26784, 31232], dtype=uint16),
#   array([36672, 37376, 35072, ..., 34912, 35616, 33056], dtype=uint16),
#   array([34912, 32256, 32832, ..., 32256, 31488, 33056], dtype=uint16),
#   array([34400, 34560, 36448, ..., 33216, 35808, 34368], dtype=uint16),
#   array([34784, 33632, 34912, ..., 31072, 29920, 30624], dtype=uint16),
#   array([30624, 32448, 34432, ..., 33568, 31776, 32096], dtype=uint16),
#   array([36704, 35360, 32736, ..., 29824, 31936, 32960], dtype=uint16),
#   array([32256, 35968, 33472, ..., 25600, 26976, 31040], dtype=uint16),
#   array([37472, 35168, 35392, ..., 31136, 27776, 27616], dtype=uint16),
#   array([31520, 31392, 32640, ..., 34528, 35712, 33184], dtype=uint16),
#   array([30880, 31904, 34304, ..., 31840, 31968, 29120], dtype=uint16),
#   array([34976, 32992, 31648, ..., 32256, 32768, 32000], dtype=uint16),
#   array([33376, 34720, 33376, ..., 30336, 25408, 29344], dtype=uint16),
#   array([33376, 33984, 32672, ..., 34016, 30016, 32160], dtype=uint16),
#   array([32224, 25376, 36416, ..., 35360, 32640, 36000], dtype=uint16),
#   array([36576, 35744, 33728, ..., 36768, 33824, 31328], dtype=uint16),
#   array([33664, 34528, 32544, ..., 32768, 33024, 32416], dtype=uint16),
#   array([31584, 35040, 30336, ..., 33408, 30720, 31040], dtype=uint16),
#   array([31904, 26176, 29536, ..., 34752, 36512, 35616], dtype=uint16),
#   array([29408, 33696, 32224, ..., 29184, 25600, 27456], dtype=uint16),
#   array([34240, 36544, 36064, ..., 33248, 35200, 34368], dtype=uint16),
#   array([34304, 33216, 32704, ..., 24832, 31456, 31104], dtype=uint16),
#   array([32512, 29376, 28096, ..., 35872, 32544, 34016], dtype=uint16),
#   array([34208, 32288, 33280, ..., 29728, 29696, 31136], dtype=uint16),
#   array([36608, 34080, 33920, ..., 34272, 36096, 33984], dtype=uint16),
#   array([33376, 31424, 36480, ..., 31232, 30592, 31808], dtype=uint16),
#   array([32416, 33728, 35168, ..., 34336, 32000, 32192], dtype=uint16),
#   array([32384, 32896, 32768, ..., 34912, 35808, 36096], dtype=uint16),
#   array([35744, 35968, 35872, ..., 32704, 32192, 26784], dtype=uint16),
#   array([35776, 32768, 33664, ..., 35744, 35008, 33824], dtype=uint16),
#   array([33216, 33152, 33088, ..., 32064, 33312, 33760], dtype=uint16),
#   array([33408, 34528, 34528, ..., 28032, 32480, 32352], dtype=uint16),
#   array([32736, 30528, 34848, ..., 35264, 32736, 34560], dtype=uint16),
#   array([34784, 33632, 33696, ..., 32704, 33536, 31296], dtype=uint16),
#   array([31008, 32128, 33600, ..., 36000, 34496, 33376], dtype=uint16),
#   array([33184, 33024, 30656, ..., 33216, 31296, 33600], dtype=uint16),
#   array([32576, 32704, 32704, ..., 32768, 32992, 34656], dtype=uint16),
#   array([33664, 36224, 33632, ..., 32064, 34560, 35008], dtype=uint16),
#   array([28768, 27616, 32736, ..., 33280, 35264, 34272], dtype=uint16),
#   array([35168, 35392, 33984, ..., 29088, 33824, 35424], dtype=uint16),
#   array([35008, 34848, 36032, ..., 32832, 32960, 32704], dtype=uint16),
#   array([36320, 35968, 37024, ..., 31328, 31200, 31168], dtype=uint16),
#   array([27008, 32480, 32768, ..., 33088, 31456, 33408], dtype=uint16),
#   array([32640, 32608, 35712, ..., 33344, 32544, 34144], dtype=uint16),
#   array([35168, 34144, 35232, ..., 31296, 33536, 33760], dtype=uint16),
#   array([34720, 31936, 33856, ..., 24128, 27808, 28992], dtype=uint16),
#   array([29824, 30784, 31904, ..., 36256, 35168, 35200], dtype=uint16),
#   array([33536, 31744, 33696, ..., 36672, 35456, 32864], dtype=uint16),
#   array([30720, 33696, 35456, ..., 34016, 35968, 33440], dtype=uint16),
#   array([33568, 32000, 32896, ..., 30624, 29248, 31008], dtype=uint16),
#   array([31456, 34336, 35680, ..., 33952, 35008, 33696], dtype=uint16),
#   array([31008, 31904, 32256, ..., 33024, 33568, 32288], dtype=uint16),
#   array([30080, 30784, 32448, ..., 36800, 37248, 35264], dtype=uint16),
#   array([33216, 34112, 34592, ..., 32192, 34048, 36672], dtype=uint16),
#   array([32672, 33344, 36000, ..., 32672, 34848, 34272], dtype=uint16),
#   array([35968, 33632, 33536, ..., 26432, 24576, 30400], dtype=uint16),
#   array([31328, 31488, 33504, ..., 34464, 34432, 32704], dtype=uint16),
#   array([34592, 32992, 33984, ..., 33184, 33792, 35328], dtype=uint16),
#   array([31360, 30144, 29632, ..., 33344, 33536, 33152], dtype=uint16),
#   array([36640, 36320, 36032, ..., 35200, 34432, 34656], dtype=uint16),
#   array([27744, 29216, 38784, ..., 30240, 28640, 33120], dtype=uint16),
#   array([33760, 31840, 31840, ..., 32864, 34176, 34720], dtype=uint16),
#   array([34560, 27872, 28224, ..., 29760, 32256, 29952], dtype=uint16),
#   array([33440, 34272, 32672, ..., 30816, 32544, 32000], dtype=uint16),
#   array([32192, 34240, 37440, ..., 31168, 28544, 31136], dtype=uint16),
#   array([34880, 30944, 34752, ..., 30688, 29472, 32704], dtype=uint16),
#   array([33280, 35296, 35808, ..., 30880, 34080, 31264], dtype=uint16),
#   array([34336, 32352, 34848, ..., 29376, 26528, 32416], dtype=uint16),
#   array([26912, 23840, 32576, ..., 34592, 35328, 32608], dtype=uint16),
#   array([30112, 28256, 32896, ..., 32992, 35008, 34848], dtype=uint16),
#   array([38368, 29568, 29504, ..., 30976, 35232, 35008], dtype=uint16),
#   array([35072, 38176, 32544, ..., 23456, 24992, 31232], dtype=uint16),
#   array([35168, 35104, 35584, ..., 35392, 36064, 36800], dtype=uint16),
#   array([35744, 33824, 32032, ..., 31712, 33472, 32096], dtype=uint16),
#   array([30976, 32608, 38112, ..., 26016, 32960, 31712], dtype=uint16),
#   array([25568, 31968, 35200, ..., 32352, 35136, 36384], dtype=uint16),
#   array([34368, 35936, 32800, ..., 35712, 36800, 35232], dtype=uint16),
#   array([37280, 30112, 33504, ..., 34240, 34048, 32512], dtype=uint16),
#   array([35552, 37984, 32128, ..., 35008, 33120, 33184], dtype=uint16),
#   array([31424, 35968, 34592, ..., 33504, 35296, 34080], dtype=uint16),
#   array([36064, 36576, 33504, ..., 33120, 33856, 34016], dtype=uint16),
#   array([33856, 30368, 36960, ..., 31744, 33728, 35840], dtype=uint16),
#   array([34048, 32512, 33440, ..., 34816, 35424, 34784], dtype=uint16),
#   array([33568, 31936, 37408, ..., 33568, 32736, 32192], dtype=uint16),
#   array([30912, 35424, 39776, ..., 29152, 36480, 33504], dtype=uint16),
#   array([33376, 38816, 34176, ..., 23744, 31968, 31040], dtype=uint16),
#   array([32320, 32928, 32288, ..., 36512, 34752, 31168], dtype=uint16),
#   array([34656, 27584, 28704, ..., 33632, 32576, 30400], dtype=uint16),
#   array([32800, 31776, 31968, ..., 33600, 37504, 32384], dtype=uint16),
#   array([32096, 33984, 35488, ..., 34368, 32800, 30336], dtype=uint16),
#   array([35200, 35840, 35392, ..., 29952, 28896, 29280], dtype=uint16),
#   array([30112, 29152, 29856, ..., 30784, 31648, 30464], dtype=uint16),
#   array([36064, 35168, 36960, ..., 31616, 35136, 35328], dtype=uint16),
#   array([38368, 39232, 37824, ..., 32320, 34560, 34656], dtype=uint16),
#   array([34176, 31840, 30144, ..., 31712, 29056, 25184], dtype=uint16),
#   array([33056, 33216, 35392, ..., 29984, 32000, 30240], dtype=uint16),
#   array([35616, 39392, 36544, ..., 35424, 35968, 35616], dtype=uint16),
#   array([35136, 34784, 34080, ..., 35520, 35648, 33376], dtype=uint16),
#   array([35392, 34656, 35840, ..., 32064, 29088, 33440], dtype=uint16),
#   array([30976, 30592, 32608, ..., 30240, 32480, 32704], dtype=uint16),
#   array([35744, 37184, 36032, ..., 30336, 30816, 30304], dtype=uint16),
#   array([32480, 29824, 27104, ..., 34080, 33056, 33536], dtype=uint16),
#   array([30720, 29632, 32576, ..., 28992, 27648, 32800], dtype=uint16),
#   array([34528, 36160, 36352, ..., 33952, 32992, 30496], dtype=uint16),
#   array([37056, 31680, 31584, ..., 32512, 31136, 29568], dtype=uint16),
#   array([35744, 36128, 33408, ..., 34784, 32608, 35776], dtype=uint16),
#   array([35680, 35680, 37824, ..., 34112, 32832, 31200], dtype=uint16),
#   array([31712, 34848, 34816, ..., 34848, 33792, 33120], dtype=uint16),
#   array([36256, 33792, 32736, ..., 31776, 33664, 31712], dtype=uint16),
#   array([32608, 36128, 32960, ..., 29248, 27808, 27936], dtype=uint16),
#   array([37536, 36704, 35008, ..., 34624, 32992, 28576], dtype=uint16),
#   array([31776, 33472, 34336, ..., 33632, 35680, 35328], dtype=uint16),
#   array([29536, 31936, 34976, ..., 33696, 32864, 31808], dtype=uint16),
#   array([34400, 32640, 31936, ..., 31104, 34272, 32448], dtype=uint16),
#   array([34464, 33760, 34240, ..., 31968, 32416, 28192], dtype=uint16),
#   array([34624, 33024, 33088, ..., 33952, 34336, 31072], dtype=uint16),
#   array([28512, 31552, 34112, ..., 33440, 36192, 33312], dtype=uint16),
#   array([37472, 35712, 35456, ..., 35200, 35904, 35648], dtype=uint16),
#   array([35744, 34272, 34560, ..., 34464, 30912, 33632], dtype=uint16),
#   array([35328, 34752, 32160, ..., 32768, 34368, 32832], dtype=uint16),
#   array([31456, 29024, 34240, ..., 33952, 33888, 33504], dtype=uint16),
#   array([35456, 35968, 35680, ..., 33120, 31264, 27584], dtype=uint16),
#   array([36128, 36864, 36672, ..., 33440, 34656, 36320], dtype=uint16),
#   array([33696, 34848, 31552, ..., 32608, 23936, 30144], dtype=uint16),
#   array([33120, 28384, 29504, ..., 35232, 33824, 32864], dtype=uint16),
#   array([34784, 33568, 35136, ..., 34528, 32512, 32416], dtype=uint16),
#   array([37088, 36224, 35648, ..., 35456, 34816, 35296], dtype=uint16),
#   array([36992, 36000, 33920, ..., 35168, 29920, 28992], dtype=uint16),
#   array([36352, 35488, 36064, ..., 34944, 33760, 32640], dtype=uint16),
#   array([34144, 33984, 34688, ..., 37024, 35648, 35840], dtype=uint16),
#   array([37344, 35936, 35200, ..., 34784, 31968, 34464], dtype=uint16),
#   array([35168, 34912, 33728, ..., 36224, 35712, 36512], dtype=uint16),
#   array([34048, 33632, 33792, ..., 34816, 29312, 34432], dtype=uint16),
#   array([35392, 36000, 33184, ..., 36224, 29280, 32896], dtype=uint16),
#   array([29472, 33952, 33600, ..., 34400, 35008, 33216], dtype=uint16),
#   array([36384, 35296, 35616, ..., 30752, 34336, 32640], dtype=uint16),
#   array([33376, 34176, 33856, ..., 32896, 35712, 33344], dtype=uint16),
#   array([34432, 32512, 27072, ..., 31136, 33280, 33088], dtype=uint16),
#   array([34624, 35008, 32800, ..., 28672, 32352, 33856], dtype=uint16),
#   array([36064, 35360, 33216, ..., 34944, 33600, 36352], dtype=uint16),
#   array([27392, 31104, 33760, ..., 31616, 31680, 34720], dtype=uint16),
#   array([35456, 34848, 35680, ..., 35104, 29888, 35104], dtype=uint16),
#   array([36224, 34464, 36288, ..., 31456, 33088, 33440], dtype=uint16),
#   array([35296, 35840, 38176, ..., 33344, 30400, 31232], dtype=uint16),
#   array([31648, 34240, 34752, ..., 31232, 31168, 31520], dtype=uint16),
#   array([35008, 34944, 34336, ..., 30624, 33568, 33504], dtype=uint16),
#   array([32640, 36064, 34912, ..., 33024, 32032, 34304], dtype=uint16),
#   array([31392, 34400, 36544, ..., 29728, 26048, 33056], dtype=uint16),
#   array([32128, 31904, 34816, ..., 35392, 37888, 38048], dtype=uint16),
#   array([32160, 31680, 32416, ..., 34592, 38464, 36640], dtype=uint16),
#   array([35040, 34976, 34912, ..., 34464, 35904, 37056], dtype=uint16),
#   array([33216, 34592, 34176, ..., 32000, 32608, 31104], dtype=uint16),
#   array([33376, 34176, 35360, ..., 31168, 36224, 34976], dtype=uint16),
#   array([34400, 32928, 33920, ..., 33376, 33664, 32192], dtype=uint16),
#   array([33280, 30688, 33824, ..., 33120, 35328, 35904], dtype=uint16),
#   array([35072, 34784, 33760, ..., 33056, 32224, 34176], dtype=uint16),
#   array([35584, 35488, 34656, ..., 33056, 32256, 34240], dtype=uint16),
#   array([40000, 36928, 35296, ..., 35520, 28288, 25728], dtype=uint16),
#   array([33536, 34016, 36736, ..., 34560, 32224, 35712], dtype=uint16),
#   array([35136, 33600, 33344, ..., 29728, 32032, 36352], dtype=uint16),
#   array([34464, 34112, 31936, ..., 33856, 33376, 33344], dtype=uint16),
#   array([36288, 35616, 36768, ..., 34784, 35168, 31168], dtype=uint16),
#   array([31328, 32864, 40800, ..., 34208, 31552, 32608], dtype=uint16),
#   array([33568, 32480, 32352, ..., 29024, 33184, 36736], dtype=uint16),
#   array([30848, 29472, 32128, ..., 31008, 29952, 32000], dtype=uint16),
#   array([35872, 35840, 36000, ..., 33408, 31264, 33184], dtype=uint16),
#   array([36288, 35744, 36896, ..., 34880, 33056, 31200], dtype=uint16),
#   array([32864, 35072, 31968, ..., 33792, 35488, 32000], dtype=uint16),
#   array([33120, 37152, 34752, ..., 36832, 30528, 36576], dtype=uint16),
#   array([34976, 33760, 38240, ..., 27360, 29088, 27168], dtype=uint16),
#   array([30432, 26880, 34304, ..., 39616, 35936, 32960], dtype=uint16),
#   array([28800, 31520, 35552, ..., 36256, 34048, 33920], dtype=uint16),
#   array([34496, 32480, 32224, ..., 30752, 33248, 32704], dtype=uint16),
#   array([33920, 35136, 35968, ..., 29632, 27584, 30240], dtype=uint16),
#   array([33216, 34336, 36160, ..., 35456, 35232, 34880], dtype=uint16),
#   array([35424, 33152, 34912, ..., 33056, 34944, 38304], dtype=uint16),
#   array([36224, 34336, 37952, ..., 34496, 25696, 31392], dtype=uint16),
#   array([31424, 35744, 35744, ..., 29280, 31200, 36064], dtype=uint16),
#   array([35488, 37280, 34656, ..., 37184, 36704, 38560], dtype=uint16),
#   array([34176, 30336, 34272, ..., 35200, 34272, 38336], dtype=uint16),
#   array([38048, 36160, 34016, ..., 34592, 36544, 33056], dtype=uint16),
#   array([36288, 37312, 32832, ..., 31392, 34464, 34560], dtype=uint16),
#   array([36032, 36288, 33088, ..., 34976, 34592, 35584], dtype=uint16),
#   array([36128, 37152, 36416, ..., 33664, 32992, 33824], dtype=uint16),
#   array([35072, 35200, 33184, ..., 33568, 35744, 35200], dtype=uint16),
#   array([34016, 33120, 35200, ..., 34976, 35104, 33504], dtype=uint16),
#   array([37120, 38272, 40320, ..., 33792, 27584, 38016], dtype=uint16),
#   ...]}

# %%
import tensorflow.keras as k

inp = k.layers.Input(shape=(1536, 1), dtype="float32")

#flatten and fully connected layer
out, weights = k.layers.AdditiveAttention(name="a")([inp, inp], return_attention_scores=True)


model = k.Model(inputs=inp, outputs=out)
model.compile(optimizer=k.optimizers.Adam(lr=1e-4), loss=k.losses.BinaryCrossentropy(from_logits=True))
model.summary()
